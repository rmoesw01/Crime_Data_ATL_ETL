# %%
import pandas as pd
import os
import glob

# %%
#Read in all CSVs to a dataframe using glob
# This code was inspired by the stackoverflow thread:    https://stackoverflow.com/questions/20906474/import-multiple-csv-files-into-pandas-and-concatenate-into-one-dataframe

apd_raw_df = pd.concat(map(pd.read_csv, glob.glob('Data_files/APD_data_2018_to_2020/*.csv')))

# %%
#review raw data
apd_raw_df
# Out:
#              UC2_Literal  Report Number Report Date  \
# 0     ROBBERY-PEDESTRIAN      180312381  01/31/2018
# 1     ROBBERY-PEDESTRIAN      180310247  01/31/2018
# 2     ROBBERY-PEDESTRIAN      180310249  01/31/2018
# 3     ROBBERY-PEDESTRIAN      180312606  01/31/2018
# 4            AGG ASSAULT      180310884  01/31/2018
# ...                  ...            ...         ...
# 1652          AUTO THEFT      201530392    6/1/2020
# 1653             LARCENY      201530422    6/1/2020
# 1654             LARCENY      201530516    6/1/2020
# 1655          AUTO THEFT      201530525    6/1/2020
# 1656            BURGLARY      201530609    6/1/2020
#
#                                    Location Beat             Neigborhood NPU  \
# 0                     1695 MARIETTA BLVD NW  203              Hills Park   D
# 1                2350 CHESHIRE BRIDGE RD NE  212  Lindridge/Martin Manor   F
# 2     1305 OAKLAND DR SW @OAKLAND CITY PARK  403            Oakland City   S
# ...

# %%
#create new dataframe with desired columns
apd_df = apd_df_raw[['UC2_Literal', 'Report Number', 'Report Date', 'Location', 'Beat', 'Neigborhood', 'NPU', 'Lat', 'Long']].copy()

# %%
#rename the UC2_Literal column
apd_df = apd_df.rename(columns={'UC2_Literal': 'Crime Type'})
apd_df
# Out:
#               Crime Type  Report Number Report Date  \
# 0     ROBBERY-PEDESTRIAN      180312381  01/31/2018
# 1     ROBBERY-PEDESTRIAN      180310247  01/31/2018
# 2     ROBBERY-PEDESTRIAN      180310249  01/31/2018
# 3     ROBBERY-PEDESTRIAN      180312606  01/31/2018
# 4            AGG ASSAULT      180310884  01/31/2018
# ...                  ...            ...         ...
# 1652          AUTO THEFT      201530392    6/1/2020
# 1653             LARCENY      201530422    6/1/2020
# 1654             LARCENY      201530516    6/1/2020
# 1655          AUTO THEFT      201530525    6/1/2020
# 1656            BURGLARY      201530609    6/1/2020
#
#                                    Location Beat             Neigborhood NPU  \
# 0                     1695 MARIETTA BLVD NW  203              Hills Park   D
# 1                2350 CHESHIRE BRIDGE RD NE  212  Lindridge/Martin Manor   F
# 2     1305 OAKLAND DR SW @OAKLAND CITY PARK  403            Oakland City   S
# ...

# %%
#save merged data to csv
apd_df.to_csv('merged_2018_to_2020.csv',index=False)

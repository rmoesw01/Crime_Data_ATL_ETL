# %%
# Dependencies
import os
import pandas as pd

# %%
# Set path for US Police Shootings Data File
input_file = os.path.join('Data_Files', 'police_shootings_us.csv')

# %%
# Setting chosen state and city
state = 'GA'
city = 'Atlanta'

# %%
# Pull csv into a pandas dataframe
shootings = pd.read_csv(input_file)
shootings
# Out:
#         id                name        date   manner_of_death       armed  \
# 0        3          Tim Elliot  2015-01-02              shot         gun
# 1        4    Lewis Lee Lembke  2015-01-02              shot         gun
# 2        5  John Paul Quintero  2015-01-03  shot and Tasered     unarmed
# 3        8     Matthew Hoffman  2015-01-04              shot  toy weapon
# 4        9   Michael Rodriguez  2015-01-04              shot    nail gun
# ...    ...                 ...         ...               ...         ...
# 4890  5916     Rayshard Brooks  2020-06-12              shot       Taser
# 4891  5925      Caine Van Pelt  2020-06-12              shot         gun
# 4892  5918        Hannah Fizer  2020-06-13              shot     unarmed
# 4893  5921      William Slyter  2020-06-13              shot         gun
# 4894  5924      Nicholas Hirsh  2020-06-15              shot         gun
#
#        age gender      race           city state  signs_of_mental_illness  \
# ...

# %%
shootings['age'] = round(shootings['age'],0)

# %%
shootings.count()
# Out:
# id                         4895
# name                       4895
# date                       4895
# manner_of_death            4895
# armed                      4895
# age                        4895
# gender                     4895
# race                       4895
# city                       4895
# state                      4895
# signs_of_mental_illness    4895
# threat_level               4895
# flee                       4895
# body_camera                4895
# arms_category              4895
# dtype: int64

# %%
# Filter the shootings dataframe to just show the records for the selected state
shootings_state = shootings.loc[shootings['state']==state]
shootings_state
# Out:
#         id                     name        date manner_of_death    armed  \
# 81     120           Anthony Purvis  2015-02-03            shot      gun
# 131    174    Michael Wayne Smashey  2015-02-23            shot    knife
# 132    175        Anthony Giaquinta  2015-02-23            shot      gun
# 142    184  Crystal Lee Miley Harry  2015-02-26            shot      gun
# 170    205             Anthony Hill  2015-03-09            shot  unarmed
# ...    ...                      ...         ...             ...      ...
# 4787  5768    Farron Morris Hammond  2020-04-25            shot      gun
# 4824  5794           Yassin Mohamed  2020-05-09            shot     rock
# 4837  5826     Wallace Dean Staples  2020-05-16            shot      gun
# 4868  5850      Momodou Lamin Sisay  2020-05-29            shot      gun
# 4890  5916          Rayshard Brooks  2020-06-12            shot    Taser
#
#        age gender   race            city state  signs_of_mental_illness  \
# ...

# %%
# Filter the shootings dataframe to just show the records for the selected city
shootings_city = shootings_state.loc[shootings_state['city']==city]
shootings_city
# Out:
#         id                    name        date manner_of_death       armed  \
# 170    205            Anthony Hill  2015-03-09            shot     unarmed
# 321    421        Alexia Christian  2015-04-29            shot         gun
# 881   1044            Darius Smith  2015-11-30            shot         gun
# 1281  1494            Cin Lam Mung  2016-04-27            shot     machete
# 1419  1647    Deravis Caine Rogers  2016-06-22            shot     unarmed
# 1947  2267       Deaundre Phillips  2017-01-26            shot         gun
# 2187  2542           Avery Richard  2017-04-28            shot         gun
# 2442  2834          Quintas Harris  2017-08-02            shot         gun
# 2543  2956           Scout Schultz  2017-09-16            shot       knife
# 2880  3379        Mitchell Kitchen  2018-02-03            shot  toy weapon
# 2893  3395            David Darden  2018-02-09            shot     vehicle
# ...

# %%
# Create output file paths
output_state = os.path.join('Data_Files', 'Shootings_Filtered', f'police_shootings_{state}.csv')
output_city = os.path.join('Data_Files', 'Shootings_Filtered', f'police_shootings_{state}_{city}.csv')

# %%
# Output DataFrames to csv files
shootings_state.to_csv(output_state, index=False)
shootings_city.to_csv(output_city, index=False)
